# %%
import pandas as pd
import os

# Reemplaza 'ruta/al/archivo.csv' con la ruta a tu archivo CSV
archivo_csv = './Dataset-IEESQuito/1 CENTRO  DE ATENCIÓN AMBULATORIA  BATÁN.csv'

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(archivo_csv)

# %%
df
# Out:
#                                             NBa7we src  \
# 0    https://lh3.googleusercontent.com/a-/ALV-UjWVe...
# 1    https://lh3.googleusercontent.com/a-/ALV-UjU0I...
# 2    https://lh3.googleusercontent.com/a-/ALV-UjVG3...
# 3    https://lh3.googleusercontent.com/a-/ALV-UjWbB...
# 4    https://lh3.googleusercontent.com/a-/ALV-UjVNh...
# ..                                                 ...
# 131  https://lh3.googleusercontent.com/a/ACg8ocKeVz...
# 132  https://lh3.googleusercontent.com/a/ACg8ocLQtp...
# 133  https://lh3.googleusercontent.com/a-/ALV-UjXMd...
# 134  https://lh3.googleusercontent.com/a-/ALV-UjWuy...
# 135  https://lh3.googleusercontent.com/a-/ALV-UjXL3...
#
#                              d4r55                                      RfnDt  \
# 0                  Martin Iturbide  Local Guide · 244 opiniones · 1,004 fotos
# 1                       Paula Loor                                  1 opinión
# 2                      José Marcos                       5 opiniones · 1 foto
# 3                    Yuly Tinitana                                2 opiniones
# 4                     Diego Alexis  Local Guide · 192 opiniones · 1,891 fotos
# ..                             ...                                        ...
# 131                 mafer palomino                                        NaN
# 132  Nicolas Patricio Yumbo Chimbo                                        NaN
# 133                  Marcelo Morán                                  1 opinión
# 134                  Pablo Padilla                         1 opinión · 1 foto
# 135             César Naranjo Díaz                                        NaN
#
#               rsqaWe                                             wiI7pd dSlJg  \
# 0       Hace 2 meses  Un maltrato increíble. El guardia no deja entr...     
# 1    4 semanas atrás  Pésimo servicio. Tiempo de espera de más de 4 ...     
# 2      Hace 11 meses  Hoy 27/06/23, necesitaba saber que paso con un...     
# 3        Hace un mes  Pesimo servicio 3 horas para atencion y 3 maa ...     
# 4        Hace un año  El servicio lento, inoperante, burocrático, de...     
# ..               ...                                                ...   ...
# 131      Hace 8 años                                                NaN   NaN
# 132      Hace 9 años                                                NaN   NaN
# 133     Hace 10 años                                                NaN   NaN
# 134     Hace 10 años                                                NaN   NaN
# 135     Hace 12 años                                                NaN   NaN
#
#        Hzvxle  pkWtMe dSlJg 2      znYl0   znYl0 2
# 0    Me gusta     2.0         Compartir       NaN
# 1    Me gusta     1.0         Compartir       NaN
# 2    Me gusta     3.0         Compartir       NaN
# 3         NaN     NaN         Compartir  Me gusta
# 4    Me gusta    17.0         Compartir       NaN
# ..        ...     ...     ...        ...       ...
# 131       NaN     NaN     NaN        NaN       NaN
# 132       NaN     NaN     NaN        NaN       NaN
# 133       NaN     NaN     NaN        NaN       NaN
# 134       NaN     NaN     NaN        NaN       NaN
# 135       NaN     NaN     NaN        NaN       NaN
#
# [136 rows x 11 columns]

# %%
# Reemplaza 'nombre_columna' con el nombre de la columna que deseas extraer
comentario = 'wiI7pd'  # Especifica el nombre de la columna que quieres extraer

# Seleccionar la columna deseada
columna_extraida = df[[comentario]]  # Se usa doble corchete para mantener el formato DataFrame

# Reemplaza 'nuevo_archivo.csv' con el nombre del nuevo archivo CSV
nuevo_archivo_csv = 'nuevo_archivo.csv'
nueva_ruta = f'./Dataset-Comentarios/{nuevo_archivo_csv}'

# Guardar la columna extraída en un nuevo archivo CSV
columna_extraida.to_csv(nueva_ruta, index=False)

print(f"Columna '{nombre_columna}' extraída y guardada en '{nueva_ruta}'")
