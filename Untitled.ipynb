# %%
import pandas as pd

# Reemplaza 'ruta/al/archivo.csv' con la ruta a tu archivo CSV
archivo_csv = './Dataset_IESSQuito/google (9).csv'

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(archivo_csv)

# %%
df
# Out:
#                                            yC3ZMb href  \
# 0    https://www.google.com/maps/contrib/1029830953...
# 1    https://www.google.com/maps/contrib/1080697676...
# 2    https://www.google.com/maps/contrib/1013736620...
# 3    https://www.google.com/maps/contrib/1119138616...
# 4    https://www.google.com/maps/contrib/1145604856...
# ..                                                 ...
# 131  https://www.google.com/maps/contrib/1072330678...
# 132  https://www.google.com/maps/contrib/1081261160...
# 133  https://www.google.com/maps/contrib/1124832256...
# 134  https://www.google.com/maps/contrib/1079565951...
# 135  https://www.google.com/maps/contrib/1163763483...
#
#                             Vpc5Fe                               GSM50 enjdgf  \
# 0                  Martin Iturbide  Local Guide244 opiniones1004 fotos      ·
# 1                       Paula Loor                           1 opinión    NaN
# 2                      José Marcos                   5 opiniones1 foto      ·
# 3                    Yuly Tinitana                         2 opiniones    NaN
# 4                     Diego Alexis  Local Guide192 opiniones1891 fotos      ·
# ..                             ...                                 ...    ...
# 131                 mafer palomino                                 NaN    NaN
# 132  Nicolas Patricio Yumbo Chimbo                                 NaN    NaN
# 133                  Marcelo Morán                           1 opinión    NaN
# 134                  Pablo Padilla                     1 opinión1 foto      ·
# 135             César Naranjo Díaz                                 NaN    NaN
#
#     enjdgf 2                                        KgoSse href  \
# 0          ·  https://www.google.com/local/review/rap/report...
# 1        NaN  https://www.google.com/local/review/rap/report...
# 2        NaN  https://www.google.com/local/review/rap/report...
# 3        NaN  https://www.google.com/local/review/rap/report...
# 4          ·  https://www.google.com/local/review/rap/report...
# ..       ...                                                ...
# 131      NaN  https://www.google.com/local/review/rap/report...
# 132      NaN  https://www.google.com/local/review/rap/report...
# 133      NaN  https://www.google.com/local/review/rap/report...
# 134      NaN  https://www.google.com/local/review/rap/report...
# 135      NaN  https://www.google.com/local/review/rap/report...
#
#               y3Ibjb                                             OA1nbd  \
# 0       Hace 2 meses  Un maltrato increíble. El guardia no deja entr...
# 1    3 semanas atrás  Pésimo servicio. Tiempo de espera de más de 4 ...
# 2      Hace 11 meses  Hoy 27/06/23, necesitaba saber que paso con un...
# 3    4 semanas atrás  Pesimo servicio 3 horas para atencion y 3 maa ...
# 4        Hace un año  El servicio lento, inoperante, burocrático, de...
# ..               ...                                                ...
# 131      Hace 8 años                                                NaN
# 132      Hace 9 años                                                NaN
# 133     Hace 10 años                                                NaN
# 134     Hace 10 años                                                NaN
# 135     Hace 11 años                                                NaN
#
#      XT8VNe
# 0       2.0
# 1       1.0
# 2       3.0
# 3       NaN
# 4      17.0
# ..      ...
# 131     NaN
# 132     NaN
# 133     NaN
# 134     NaN
# 135     NaN
#
# [136 rows x 9 columns]
